# %% [markdown]
# ## Libraries

# %%
import itertools
#To browse and access files and folders in the Local folders in the system
import os
#Import OpenCV
import cv2
import pandas as pd
#Libray for Visualization of data
import matplotlib.pylab as plt
import numpy as np
import imghdr

import tensorflow as tf
import tensorflow_hub as hub

print("TF version:", tf.__version__)
print("Hub version:", hub.__version__)
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")
# Out:
# TF version: 2.11.0
# Hub version: 0.12.0
# GPU is NOT AVAILABLE

# %% [markdown]
# ## Checking data

# %%
#Assign the dataset folder name as data_dir
data_dir = 'lung-cancer'
#List the contents of the folder Lung-Cancer
os.listdir(data_dir)
# Out:
# ['Benign',
#  'IQ-OTH_NCCD lung cancer dataset.txt',
#  'Malignant',
#  'Normal',
#  'Test cases']

# %%
os.listdir(os.path.join(data_dir, 'Benign'))
# Out:
# ['Bengin case (1).jpg',
#  'Bengin case (10).jpg',
#  'Bengin case (100).jpg',
#  'Bengin case (101).jpg',
#  'Bengin case (102).jpg',
#  'Bengin case (103).jpg',
#  'Bengin case (104).jpg',
#  'Bengin case (105).jpg',
#  'Bengin case (106).jpg',
#  'Bengin case (107).jpg',
#  'Bengin case (108).jpg',
#  'Bengin case (109).jpg',
#  'Bengin case (11).jpg',
#  'Bengin case (110).jpg',
#  'Bengin case (111).jpg',
#  'Bengin case (112).jpg',
#  'Bengin case (113).jpg',
#  'Bengin case (114).jpg',
#  'Bengin case (115).jpg',
#  'Bengin case (116).jpg',
#  'Bengin case (117).jpg',
#  'Bengin case (118).jpg',
#  'Bengin case (119).jpg',
#  'Bengin case (12).jpg',
#  'Bengin case (120).jpg',
#  'Bengin case (13).jpg',
#  'Bengin case (14).jpg',
#  'Bengin case (15).jpg',
#  'Bengin case (16).jpg',
#  'Bengin case (17).jpg',
#  'Bengin case (18).jpg',
#  'Bengin case (19).jpg',
#  'Bengin case (2).jpg',
#  'Bengin case (20).jpg',
#  'Bengin case (21).jpg',
#  'Bengin case (22).jpg',
# ...

# %%
for image_class in os.listdir(data_dir):
    for image in os.listdir(os.path.join(data_dir, image_class)):
        print(image)
# Out:
# Bengin case (1).jpg
# Bengin case (10).jpg
# Bengin case (100).jpg
# Bengin case (101).jpg
# Bengin case (102).jpg
# Bengin case (103).jpg
# Bengin case (104).jpg
# Bengin case (105).jpg
# Bengin case (106).jpg
# Bengin case (107).jpg
# Bengin case (108).jpg
# Bengin case (109).jpg
# Bengin case (11).jpg
# Bengin case (110).jpg
# Bengin case (111).jpg
# Bengin case (112).jpg
# Bengin case (113).jpg
# Bengin case (114).jpg
# Bengin case (115).jpg
# Bengin case (116).jpg
# Bengin case (117).jpg
# Bengin case (118).jpg
# Bengin case (119).jpg
# Bengin case (12).jpg
# Bengin case (120).jpg
# Bengin case (13).jpg
# Bengin case (14).jpg
# Bengin case (15).jpg
# Bengin case (16).jpg
# Bengin case (17).jpg
# Bengin case (18).jpg
# Bengin case (19).jpg
# Bengin case (2).jpg
# Bengin case (20).jpg
# Bengin case (21).jpg
# Bengin case (22).jpg
# Bengin case (23).jpg
# Bengin case (24).jpg
# Bengin case (25).jpg
# Bengin case (26).jpg
# Bengin case (27).jpg
# Bengin case (28).jpg
# ...

# %%
#Showing image as Numpy Array
cv2.imread(os.path.join('lung-cancer', 'Normal', 'Normal case (1).jpg'))
# Out:
# array([[[38, 38, 38],
#         [38, 38, 38],
#         [38, 38, 38],
#         ...,
#         [38, 38, 38],
#         [38, 38, 38],
#         [38, 38, 38]],
#
#        [[38, 38, 38],
#         [38, 38, 38],
#         [38, 38, 38],
#         ...,
#         [38, 38, 38],
#         [38, 38, 38],
#         [38, 38, 38]],
#
#        [[38, 38, 38],
#         [38, 38, 38],
#         [38, 38, 38],
#         ...,
#         [38, 38, 38],
#         [38, 38, 38],
#         [38, 38, 38]],
#
#        ...,
#
#        [[38, 38, 38],
#         [38, 38, 38],
#         [38, 38, 38],
#         ...,
#         [38, 38, 38],
#         [38, 38, 38],
#         [38, 38, 38]],
#
#        [[38, 38, 38],
#         [38, 38, 38],
#         [38, 38, 38],
#         ...,
#         [38, 38, 38],
#         [38, 38, 38],
#         [38, 38, 38]],
#
#        [[38, 38, 38],
#         [38, 38, 38],
#         [38, 38, 38],
#         ...,
#         [38, 38, 38],
#         [38, 38, 38],
#         [38, 38, 38]]], dtype=uint8)

# %%
#Read Images using OpenCv
img = cv2.imread(os.path.join('lung-cancer', 'Normal', 'Normal case (1).jpg'))
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (512, 512, 3)

# %%
plt.imshow(img)
plt.show()

# %%
tf.data.Dataset
# Out:
# tensorflow.python.data.ops.dataset_ops.DatasetV2

# %% [markdown]
# ## Loading Data
